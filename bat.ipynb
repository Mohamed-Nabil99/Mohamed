# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Nabil99/Mohamed/blob/main/bat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def distance(city1, city2):
    # Calculate the Euclidean distance between two cities
    return np.linalg.norm(city1 - city2)

def evaluate_fitness(solution, cities):
    # Calculate the total distance of the TSP tour
    num_cities = len(cities)
    total_distance = 0.0
    for i in range(num_cities - 1):
        total_distance += distance(cities[solution[i]], cities[solution[i+1]])
    total_distance += distance(cities[solution[-1]], cities[solution[0]])

    # Return the inverse of the total distance as the fitness value
    fitness = 1.0 / total_distance

    return fitness
    
def local_search(solution, cities):
    # Perform 2-opt local search to improve the TSP solution
    num_cities = len(solution)
    best_solution = solution.copy()
    best_distance = evaluate_fitness(best_solution, cities)
    improved = True
    while improved:
        improved = False
        for i in range(1, num_cities - 1):
            for j in range(i + 1, num_cities):
                new_solution = best_solution.copy()
                new_solution[i:j] = list(reversed(best_solution[i:j]))
                new_distance = evaluate_fitness(new_solution, cities)
                if new_distance < best_distance:
                    best_solution = new_solution
                    best_distance = new_distance
                    improved = True
    return best_solution


def bat_algorithm(num_bats, num_iterations, cities, min_frequency, max_frequency, min_loudness, max_loudness, alpha, gamma):

    num_cities = len(cities)
    dimension = num_cities

    # Initialize bats
    bats = np.zeros((num_bats, dimension), dtype=int)
    velocities = np.zeros((num_bats, dimension))
    frequencies = np.random.uniform(min_frequency, max_frequency, num_bats)
    loudness = np.random.uniform(min_loudness, max_loudness, num_bats)

    # Initialize the best solution
    best_solution = np.random.permutation(num_cities)
    best_fitness = evaluate_fitness(best_solution, cities)

    # Main loop
    for t in range(num_iterations):
        for i in range(num_bats):
            # Update bat's velocity and frequency
            velocities[i] += (bats[i] - best_solution) * frequencies[i]
            frequencies[i] = min_frequency + (max_frequency - min_frequency) * np.random.random()

            # Update bat's position
            bats[i] = np.clip(bats[i] + velocities[i], 0, num_cities-1)

            # Perform random walk exploration
            if np.random.random() > loudness[i]:
                bats[i] = np.random.permutation(num_cities)

            # Apply local search
            if np.random.random() < gamma:
                bats[i] = local_search(bats[i], cities)

            # Evaluate new solution
            fitness = evaluate_fitness(bats[i], cities)

            # Update the best solution
            if fitness < best_fitness:
                best_fitness = fitness
                best_solution = bats[i]

        print(f"Iteration {t+1}: Best fitness = {best_fitness}")

    return best_solution, best_fitness

# Example usage
num_bats = 8
num_iterations = 100
min_frequency = 0.3
max_frequency = 0.7
min_loudness = 0.0
max_loudness = 1.0
alpha = 0.5
gamma = 0.5

# Generate a random set of cities
num_cities = 20
#cities = np.random.rand(num_cities, 3)  # 2D cities with random coordinates
cities = np.random.uniform(0, 100, (num_cities, 2))

best_solution, best_fitness = bat_algorithm(num_bats, num_iterations, cities, min_frequency, max_frequency, min_loudness, max_loudness, alpha, gamma)
print("Best solution:", best_solution)
print("Best fitness:", best_fitness)
# Out:
# <ipython-input-15-2a0dd9227a6d>:16: RuntimeWarning: divide by zero encountered in double_scalars
#   fitness = 1.0 / total_distance
# Iteration 1: Best fitness = 0.0006417203956620933
# Iteration 2: Best fitness = 0.0006320448581197251
# Iteration 3: Best fitness = 0.0006314968120645472
# Iteration 4: Best fitness = 0.0006314968120645472
# Iteration 5: Best fitness = 0.0006314968120645472
# Iteration 6: Best fitness = 0.0006314968120645472
# Iteration 7: Best fitness = 0.0006308143910198988
# Iteration 8: Best fitness = 0.0006308143910198988
# Iteration 9: Best fitness = 0.0006308143910198988
# Iteration 10: Best fitness = 0.0006308143910198988
# Iteration 11: Best fitness = 0.0006308143910198988
# Iteration 12: Best fitness = 0.0006308143910198988
# Iteration 13: Best fitness = 0.0006308143910198988
# Iteration 14: Best fitness = 0.0006308143910198988
# Iteration 15: Best fitness = 0.0006308143910198988
# Iteration 16: Best fitness = 0.0006308143910198988
# Iteration 17: Best fitness = 0.0006306161682316168
# Iteration 18: Best fitness = 0.0006306161682316168
# Iteration 19: Best fitness = 0.0006306161682316168
# Iteration 20: Best fitness = 0.0006306161682316168
# Iteration 21: Best fitness = 0.0006306161682316168
# Iteration 22: Best fitness = 0.0006306161682316168
# Iteration 23: Best fitness = 0.0006306161682316168
# Iteration 24: Best fitness = 0.0006306161682316168
# Iteration 25: Best fitness = 0.0006306161682316168
# Iteration 26: Best fitness = 0.0006306161682316168
# Iteration 27: Best fitness = 0.0006306161682316168
# Iteration 28: Best fitness = 0.0006306161682316168
# Iteration 29: Best fitness = 0.0006306161682316168
# Iteration 30: Best fitness = 0.0006306161682316168
# Iteration 31: Best fitness = 0.0006306161682316168
# Iteration 32: Best fitness = 0.0006306161682316168
# Iteration 33: Best fitness = 0.0006306161682316168
# Iteration 34: Best fitness = 0.0006306161682316168
# Iteration 35: Best fitness = 0.0006306161682316168
# Iteration 36: Best fitness = 0.0006306161682316168
# Iteration 37: Best fitness = 0.0006306161682316168
# Iteration 38: Best fitness = 0.0006306161682316168
# Iteration 39: Best fitness = 0.0006306161682316168
# Iteration 40: Best fitness = 0.0006306161682316168
# Iteration 41: Best fitness = 0.0006306161682316168
# Iteration 42: Best fitness = 0.0006306161682316168
# Iteration 43: Best fitness = 0.0006306161682316168
# Iteration 44: Best fitness = 0.0006306161682316168
# Iteration 45: Best fitness = 0.0006306161682316168
# Iteration 46: Best fitness = 0.0006306161682316168
# Iteration 47: Best fitness = 0.0006306161682316168
# Iteration 48: Best fitness = 0.0006306161682316168
# Iteration 49: Best fitness = 0.0006306161682316168
# Iteration 50: Best fitness = 0.0006306161682316168
# Iteration 51: Best fitness = 0.0006306161682316168
# Iteration 52: Best fitness = 0.0006306161682316168
# Iteration 53: Best fitness = 0.0006306161682316168
# Iteration 54: Best fitness = 0.0006306161682316168
# Iteration 55: Best fitness = 0.0006306161682316168
# Iteration 56: Best fitness = 0.0006306161682316166
# Iteration 57: Best fitness = 0.0006306161682316166
# Iteration 58: Best fitness = 0.0006306161682316166
# Iteration 59: Best fitness = 0.0006306161682316166
# Iteration 60: Best fitness = 0.0006306161682316166
# Iteration 61: Best fitness = 0.0006306161682316166
# Iteration 62: Best fitness = 0.0006306161682316166
# Iteration 63: Best fitness = 0.0006306161682316166
# Iteration 64: Best fitness = 0.0006306161682316166
# Iteration 65: Best fitness = 0.0006306161682316166
# Iteration 66: Best fitness = 0.0006306161682316166
# Iteration 67: Best fitness = 0.0006306161682316166
# Iteration 68: Best fitness = 0.0006306161682316166
# Iteration 69: Best fitness = 0.0006306161682316166
# Iteration 70: Best fitness = 0.0006306161682316166
# Iteration 71: Best fitness = 0.0006306161682316166
# Iteration 72: Best fitness = 0.0006306161682316166
# Iteration 73: Best fitness = 0.0006306161682316166
# Iteration 74: Best fitness = 0.0006306161682316166
# Iteration 75: Best fitness = 0.0006306161682316166
# Iteration 76: Best fitness = 0.0006306161682316166
# Iteration 77: Best fitness = 0.0006306161682316166
# Iteration 78: Best fitness = 0.0006306161682316166
# Iteration 79: Best fitness = 0.0006306161682316166
# Iteration 80: Best fitness = 0.0006306161682316166
# Iteration 81: Best fitness = 0.0006306161682316166
# Iteration 82: Best fitness = 0.0006306161682316166
# Iteration 83: Best fitness = 0.0006306161682316166
# Iteration 84: Best fitness = 0.0006306161682316166
# Iteration 85: Best fitness = 0.0006306161682316166
# Iteration 86: Best fitness = 0.0006306161682316166
# Iteration 87: Best fitness = 0.0006306161682316166
# Iteration 88: Best fitness = 0.0006306161682316166
# Iteration 89: Best fitness = 0.0006306161682316166
# Iteration 90: Best fitness = 0.0006306161682316166
# Iteration 91: Best fitness = 0.0006306161682316166
# Iteration 92: Best fitness = 0.0006306161682316166
# Iteration 93: Best fitness = 0.0006306161682316166
# Iteration 94: Best fitness = 0.0006306161682316166
# Iteration 95: Best fitness = 0.0006306161682316166
# Iteration 96: Best fitness = 0.0006306161682316166
# Iteration 97: Best fitness = 0.0006306161682316166
# Iteration 98: Best fitness = 0.0006306161682316166
# Iteration 99: Best fitness = 0.0006306161682316166
# Iteration 100: Best fitness = 0.0006306161682316166
# Best solution: [ 0  5  2  8 16 18 19  4 15 10 11  1  6 14 13  3 17  7 12  9]
# Best fitness: 0.0006306161682316166
